# %% [markdown]
# <a href="https://colab.research.google.com/github/GaneshSelvaraj717/Ganesh-Selvaraj/blob/master/MusicEmotionClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/gdrive/MyDrive/Music_classify2022/MusicFolder/
# Out:
# /content/gdrive/MyDrive/Music_classify2022/MusicFolder

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/MyDrive/Music_classify2022/MusicFolder/"

# %%
# !kaggle competitions download -c musical-emotions-classification-in-audio-files
# Out:
# ...
#  98% 630M/641M [00:03<00:00, 191MB/s]
# 100% 641M/641M [00:03<00:00, 178MB/s]

# %%
ls
# Out:
# kaggle.json  musical-emotions-classification-in-audio-files.zip

# %%
# !unzip -q musical-emotions-classification-in-audio-files.zip

# %%
data_path = '/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train'

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import torch.nn as nn
from tqdm import tqdm
import librosa
from pathlib import Path
import torch.nn.functional as F

# %%
# Function to get the .wav files and Map the labels for each wav file
def get_files(path, extension='.wav'):
    return list(path.rglob(f'*{extension}'))
label_id = {"01": "Happy", 
            '02': "Sad", 
           }

# %%
print(label_id)
# Out:
# {'01': 'Happy', '02': 'Sad'}

# %%
# Get all files from the ravdess data folders
all_files = get_files(Path(data_path))
print(len(all_files))
# Out:
# 1873

# %%
print(all_files)
# Out:
# [PosixPath('/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train/Happy/Happy10200.wav'), PosixPath('/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train/Happy/Happy10201.wav'), PosixPath('/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train/Happy/Happy10202.wav'), PosixPath('/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train/Happy/Happy10203.wav'), PosixPath('/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train/Happy/Happy10204.wav'), PosixPath('/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train/Happy/Happy10205.wav'), PosixPath('/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train/Happy/Happy10206.wav'), PosixPath('/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train/Happy/Happy10207.wav'), PosixPath('/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train/Happy/Happy10208.wav'), PosixPath('/content/gdrive/MyDrive/Music_classify2022/MusicFolder/Train/Train/H
# ...

# %%
emotion = set([str(l).split('/')[-2] for l in all_files])

# %%
emotion
# Out:
# {'Happy', 'Sad'}

# %%
for l in all_files:
  print(str(l).split('/')[-2])
# Out:
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# Happy
# ...

# %%
# Assigning labels to each .wav file in all the actor folders
# Note: the label id starts from 0 to 7
labels = {str(l):int(l.stem.split('-')[2][-1])-1 for l in all_files}
print(len(speakers))
print(speakers)
print(labels)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-49-79592e66cadc> in <module>
#       1 # Assigning labels to each .wav file in all the actor folders
#       2 # Note: the label id starts from 0 to 7
# ----> 3 labels = {str(l):int(l.stem.split('-')[2][-1])-1 for l in all_files}
#       4 print(len(speakers))
#       5 print(speakers)
#
# <ipython-input-49-79592e66cadc> in <dictcomp>(.0)
#       1 # Assigning labels to each .wav file in all the actor folders
#       2 # Note: the label id starts from 0 to 7
# ----> 3 labels = {str(l):int(l.stem.split('-')[2][-1])-1 for l in all_files}
#       4 print(len(speakers))
#       5 print(speakers)
#
# IndexError: list index out of range
